# %%
import pandas as pd
import matplotlib.pyplot as plt

from discrete_opt import *
from sample_games import *

# %%
game = battle_of_sexes

res, log = find_best_strat(game, verbose=False, n_iter=250, init_method="equal")

fig = plt.figure(figsize=(16, 8))

ax = fig.subplots(1, game.shape[-1])

for i in range(game.shape[-1]):
    pd.DataFrame(log[i]).plot(ax=ax[i])
    
plt.show()

# %%
np.min(log[1][:,0])
# Out:
# 0.3304694672550285

# %%
np.max(log[1][:,1])
# Out:
# 0.6695305327449715

# %%
fig.savefig("bos_opt.png")
